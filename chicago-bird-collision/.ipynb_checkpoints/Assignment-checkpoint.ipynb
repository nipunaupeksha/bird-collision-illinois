# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from jupyterthemes import jtplot
jtplot.style(theme='monokai', context='notebook', ticks=True, grid=False)

# %%
lLevels=pd.read_json('light_levels.json')

# %%
fCall=pd.read_json('flight_call.json')

# %%
cData = pd.read_json('chicago_collision_data.json')

# %%
fCall.columns=["Genus","Species","Family","Flight","Flight Call","Habitat","Stratum"]

# %%
lLevels.dropna(subset=lLevels.columns[[0,1]], inplace=True)

# %%
duplicateDFRow = cData[cData.duplicated(['Date'])]
duplicateDFRow
# Out:
#              Genus     Species       Date Locality
# 6       Ammodramus     nelsoni 1986-09-12       MP
# 10      Ammodramus     nelsoni 1987-09-29       MP
# 20      Ammodramus     nelsoni 1992-05-17       MP
# 52      Ammodramus     nelsoni 2014-10-04       MP
# 57      Ammodramus   henslowii 1988-05-13       MP
# ...            ...         ...        ...      ...
# 69779    Melospiza     melodia 2016-10-19      CHI
# 69780    Melospiza     melodia 2016-10-30      CHI
# 69781  Zonotrichia     querula 2007-10-15       MP
# 69782  Zonotrichia     querula 2008-10-16       MP
# 69783  Zonotrichia  albicollis 2013-10-22      CHI
#
# [64466 rows x 4 columns]

# %%
lLevels.drop_duplicates(subset='Date', keep=False, inplace=True)

# %%
fCall['tax']=fCall.apply(lambda row: row.Family.lower().strip()+" "+row.Genus.lower().strip()+" "+row.Species.lower().strip(),axis=1)
duplicateDFRow = fCall[fCall.duplicated(['tax'])]
duplicateDFRow
# Out:
#         Genus     Species         Family  Flight Flight Call Habitat Stratum  \
# 91  Empidonax    traillii     Tyrannidae     177          No    Open   Upper
# 92  Melospiza   georgiana  Passerellidae    4910         Yes    Open   Lower
# 93      Vireo      gilvus     Vireonidae       2          No  Forest   Upper
# 94      Vireo  flavifrons     Vireonidae      12          No  Forest   Upper
# 95    Certhia   americana     Certhiidae    2676         Yes  Forest   Upper
#
#                   sName                                tax
# 91   Empidonax traillii      tyrannidae empidonax traillii
# 92  Melospiza georgiana  passerellidae melospiza georgiana
# 93         Vireo gilvus            vireonidae vireo gilvus
# 94     Vireo flavifrons        vireonidae vireo flavifrons
# 95    Certhia americana       certhiidae certhia americana

# %%
df1 = pd.merge(lLevels,cData,on='Date')
df1.describe()
# Out:
#        Light Score
# count  38822.000000
# mean      11.022230
# std        5.120323
# min        3.000000
# 25%        5.000000
# 50%       12.000000
# 75%       16.000000
# max       17.000000

# %%
df1['sName']=df1.apply(lambda row: row.Genus.strip()+" "+row.Species.strip(),axis=1)
df1.head(5)
# Out:
#         Date  Light Score      Genus    Species Locality               sName
# 0 2010-09-26           4.0  Catharus   guttatus      CHI   Catharus guttatus
# 1 2010-09-26           4.0  Catharus   guttatus      CHI   Catharus guttatus
# 2 2010-09-26           4.0  Catharus   guttatus      CHI   Catharus guttatus
# 3 2010-09-26           4.0  Catharus  ustulatus      CHI  Catharus ustulatus
# 4 2010-09-26           4.0  Catharus  ustulatus      CHI  Catharus ustulatus

# %%
df1=df1.drop(columns=["Genus","Species"])

# %%
fCall['sName']=fCall.apply(lambda row: row.Genus.strip()+" "+row.Species.strip(),axis=1)
fCall.head(5)
# Out:
#          Genus      Species         Family  Flight Flight Call Habitat  \
# 0  Zonotrichia   albicollis  Passerellidae   10133         Yes  Forest
# 1        Junco     hyemalis  Passerellidae    6303         Yes    Edge
# 2    Melospiza      melodia  Passerellidae    5124         Yes    Edge
# 3    Melospiza    georgiana  Passerellidae    4910         Yes    Open
# 4      Seiurus  aurocapilla      Parulidae    4580         Yes  Forest
#
#   Stratum                   sName
# 0   Lower  Zonotrichia albicollis
# 1   Lower          Junco hyemalis
# 2   Lower       Melospiza melodia
# 3   Lower     Melospiza georgiana
# 4   Lower     Seiurus aurocapilla

# %%
df2 = pd.merge(df1,fCall,on='sName')
df2.head(5)
# Out:
#         Date  Light Score  Locality              sName     Genus   Species  \
# 0 2010-09-26           4.0      CHI  Catharus guttatus  Catharus  guttatus
# 1 2010-09-26           4.0      CHI  Catharus guttatus  Catharus  guttatus
# 2 2010-09-26           4.0      CHI  Catharus guttatus  Catharus  guttatus
# 3 2007-10-22          15.0      CHI  Catharus guttatus  Catharus  guttatus
# 4 2007-10-22          15.0      CHI  Catharus guttatus  Catharus  guttatus
#
#      Family  Flight Flight Call Habitat Stratum
# 0  Turdidae    3729         Yes  Forest   Lower
# 1  Turdidae    3729         Yes  Forest   Lower
# 2  Turdidae    3729         Yes  Forest   Lower
# 3  Turdidae    3729         Yes  Forest   Lower
# 4  Turdidae    3729         Yes  Forest   Lower

# %%
df2.describe()
# Out:
#        Light Score         Flight
# count  39957.000000  39957.000000
# mean      10.898291   4208.933478
# std        5.091457   3272.308624
# min        3.000000      1.000000
# 25%        5.000000   1555.000000
# 50%       12.000000   3729.000000
# 75%       16.000000   6303.000000
# max       17.000000  10133.000000

# %%
sns.heatmap(df2.isnull(),yticklabels=False, cbar=False, cmap="Blues")

# %%
df2=df2.drop(columns=["sName"])
df2.head(5)
# Out:
#         Date  Light Score  Locality     Genus   Species    Family  Flight  \
# 0 2010-09-26           4.0      CHI  Catharus  guttatus  Turdidae    3729
# 1 2010-09-26           4.0      CHI  Catharus  guttatus  Turdidae    3729
# 2 2010-09-26           4.0      CHI  Catharus  guttatus  Turdidae    3729
# 3 2007-10-22          15.0      CHI  Catharus  guttatus  Turdidae    3729
# 4 2007-10-22          15.0      CHI  Catharus  guttatus  Turdidae    3729
#
#   Flight Call Habitat Stratum
# 0         Yes  Forest   Lower
# 1         Yes  Forest   Lower
# 2         Yes  Forest   Lower
# 3         Yes  Forest   Lower
# 4         Yes  Forest   Lower

# %%
df2["Date"] = pd.to_datetime(df2["Date"])
df2 = df2.sort_values(by="Date")
df2.head(10)
# Out:
#             Date  Light Score  Locality         Genus   Species  \
# 34270 2000-03-06           3.0       MP  Spizelloides   arborea
# 12331 2000-03-06           3.0       MP         Junco  hyemalis
# 35314 2000-03-06           3.0       MP     Melospiza   melodia
# 35313 2000-03-06           3.0       MP     Melospiza   melodia
# 32234 2000-03-08          15.0       MP    Passerella    iliaca
# 34796 2000-03-08          15.0       MP     Melospiza   melodia
# 34798 2000-03-08          15.0       MP     Melospiza   melodia
# 34795 2000-03-08          15.0       MP     Melospiza   melodia
# 34799 2000-03-08          15.0       MP     Melospiza   melodia
# 34800 2000-03-08          15.0       MP     Melospiza   melodia
#
#               Family  Flight Flight Call Habitat Stratum
# 34270  Passerellidae    1262         Yes    Edge   Lower
# 12331  Passerellidae    6303         Yes    Edge   Lower
# 35314  Passerellidae    5124         Yes    Edge   Lower
# 35313  Passerellidae    5124         Yes    Edge   Lower
# 32234  Passerellidae    2443         Yes    Edge   Lower
# 34796  Passerellidae    5124         Yes    Edge   Lower
# 34798  Passerellidae    5124         Yes    Edge   Lower
# 34795  Passerellidae    5124         Yes    Edge   Lower
# 34799  Passerellidae    5124         Yes    Edge   Lower
# 34800  Passerellidae    5124         Yes    Edge   Lower

# %%
df2.columns
# Out:
# Index(['Date', 'Light Score ', 'Locality', 'Genus', 'Species', 'Family',
#        'Flight', 'Flight Call', 'Habitat', 'Stratum'],
#       dtype='object')

# %%
def main(light_levels,collision_data,flight_call,output_file):
    #Load .json files to DataFrames
    lLevels=pd.read_json(light_levels)
    cData = pd.read_json(collision_data)
    fCall=pd.read_json(flight_call)
    
    #Correct the fCall DataFrame columns as given in the .docx file
    fCall.columns=["Genus","Species","Family","Flight","Flight Call","Habitat","Stratum"]
    
    #Remove rows containing NaN values from all the DataFrames
    lLevels.dropna(subset=lLevels.columns[[0,1]], inplace=True)
    cData.dropna(subset=cData.columns[[0,1,2,3]], inplace=True)
    fCall.dropna(subset=fCall.columns[[0,1,2,3,4,5,6]], inplace=True)
    
    #Since the LightScore for a certain date should be unique. we should remove duplicates from the lLevels DataFrame
    lLevels.drop_duplicates(subset='Date', keep=False, inplace=True)
    
    #The Taxonomic Ranking is  Family > Genus > Species. So we will create a separate column in fCall and remove the duplicates in that
    fCall['tax']=fCall.apply(lambda row: row.Family.lower().strip()+" "+row.Genus.lower().strip()+" "+row.Species.lower().strip(),axis=1)
    
    #since the Taxonomic name we made is unique, we can remove the duplicates accordingly.
    fCall.drop_duplicates(subset='tax', keep=False, inplace=True)
    
    #Merge lLevels DataFrame and cData based on the Date column since Date column is unique in lLevles DataFrame
    df1 = pd.merge(lLevels,cData,on='Date')
    
    #After merging that we need to merge df1 and fCall DataFrames. To do that we need to find a common column.
    #The common columns available in those DataFrames are Genus and Species.
    #So we will create a column called sName specifying "Specific Name"
